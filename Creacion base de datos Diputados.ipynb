# %%
import requests, xmltodict, pandas as pd
from zeep import Client, helpers
from datetime import datetime

# %%
def listar_ops(wsdl_url):
    c = Client(wsdl=wsdl_url)
    for svc in c.wsdl.services.values():
        for port in svc.ports.values():
            binding = port.binding
            for name, op in binding._operations.items():
                # Nombre de la operación
                args = []
                if op.input and op.input.body and op.input.body.type:
                    args = [elt[0] for elt in op.input.body.type.elements]  # nombres de parámetros
                print(f"{name}({', '.join(args)})")

# Servicio raíz (Cámara)
#listar_ops("https://opendata.camara.cl/wscamaradiputados.asmx?WSDL")
# Servicio Legislativo
#listar_ops("https://opendata.camara.cl/camaradiputados/WServices/WSLegislativo.asmx?WSDL")
# Servicio Diputado / Comisión / Común (si los necesitas)
listar_ops("https://opendata.camara.cl/camaradiputados/WServices/WSDiputado.asmx?WSDL")
#listar_ops("https://opendata.camara.cl/camaradiputados/WServices/WSComision.asmx?WSDL")
#listar_ops("https://opendata.camara.cl/camaradiputados/WServices/WSComun.asmx?WSDL")
# Out:
# retornarDiputados()
# retornarDiputado(prmDiputadoId)
# retornarDiputadosXPeriodo(prmPeriodoID)
# retornarDiputadosPeriodoActual()
# retornarDiputados()
# retornarDiputado(prmDiputadoId)
# retornarDiputadosXPeriodo(prmPeriodoID)
# retornarDiputadosPeriodoActual()
# retornarDiputados()
# retornarDiputado(prmDiputadoId)
# retornarDiputadosXPeriodo(prmPeriodoID)
# retornarDiputadosPeriodoActual()
# retornarDiputados()
# retornarDiputado(prmDiputadoId)
# retornarDiputadosXPeriodo(prmPeriodoID)
# retornarDiputadosPeriodoActual()

# %%
c = Client("https://opendata.camara.cl/camaradiputados/WServices/WSDiputado.asmx?WSDL")
res = c.service.retornarDiputados()
print(res)
# Out:
# [{
#     'Id': 208,
#     'Nombre': 'Víctor',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Pérez',
#     'ApellidoMaterno': 'Varela',
#     'FechaNacimiento': datetime.datetime(1954, 10, 18, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(1990, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(1994, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'UDI',
#                     'Nombre': 'Unión Demócrata Independiente',
#                     'Alias': 'UDI'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(1998, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2002, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'UDI',
#                     'Nombre': 'Unión Demócrata Independiente',
#                     'Alias': 'UDI'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2002, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2006, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'UDI',
#                     'Nombre': 'Unión Demócrata Independiente',
#                     'Alias': 'UDI'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(1994, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(1998, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'UDI',
#                     'Nombre': 'Unión Demócrata Independiente',
#                     'Alias': 'UDI'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 485,
#     'Nombre': 'Jorge',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Pizarro',
#     'ApellidoMaterno': 'Soto',
#     'FechaNacimiento': None,
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(1990, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(1994, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'DC',
#                     'Nombre': 'Partido Demócrata Cristiano',
#                     'Alias': 'DC'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(1994, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(1998, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'DC',
#                     'Nombre': 'Partido Demócrata Cristiano',
#                     'Alias': 'DC'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 684,
#     'Nombre': 'Sergio',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Pizarro',
#     'ApellidoMaterno': 'Mackay',
#     'FechaNacimiento': None,
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(1990, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(1994, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'DC',
#                     'Nombre': 'Partido Demócrata Cristiano',
#                     'Alias': 'DC'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 696,
#     'Nombre': 'José Alfonso',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Rodríguez',
#     'ApellidoMaterno': 'Del Río',
#     'FechaNacimiento': None,
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(1990, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(1994, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'RN',
#                     'Nombre': 'Renovación Nacional',
#                     'Alias': 'RN'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 951,
#     'Nombre': 'David',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Sandoval',
#     'ApellidoMaterno': 'Plaza',
#     'FechaNacimiento': datetime.datetime(1952, 10, 20, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2010, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2014, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'UDI',
#                     'Nombre': 'Unión Demócrata Independiente',
#                     'Alias': 'UDI'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2014, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2018, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'UDI',
#                     'Nombre': 'Unión Demócrata Independiente',
#                     'Alias': 'UDI'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 961,
#     'Nombre': 'Pedro',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Velásquez',
#     'ApellidoMaterno': 'Seguel',
#     'FechaNacimiento': datetime.datetime(1964, 8, 5, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2010, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2014, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'IND',
#                     'Nombre': 'Independientes',
#                     'Alias': 'IND'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2018, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2022, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'IND',
#                     'Nombre': 'Independientes',
#                     'Alias': 'IND'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 927,
#     'Nombre': 'Pedro',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Browne',
#     'ApellidoMaterno': 'Urrejola',
#     'FechaNacimiento': datetime.datetime(1972, 6, 29, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2010, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2014, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'RN',
#                     'Nombre': 'Renovación Nacional',
#                     'Alias': 'RN'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2017, 6, 21, 0, 0),
#                 'FechaTermino': datetime.datetime(2018, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'IND',
#                     'Nombre': 'Independientes',
#                     'Alias': 'IND'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2014, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2017, 6, 20, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'AMPL',
#                     'Nombre': 'Amplitud',
#                     'Alias': 'AMPL'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 933,
#     'Nombre': 'Aldo',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Cornejo',
#     'ApellidoMaterno': 'González',
#     'FechaNacimiento': datetime.datetime(1955, 4, 19, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(1990, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(1994, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'DC',
#                     'Nombre': 'Partido Demócrata Cristiano',
#                     'Alias': 'DC'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2010, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2014, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'DC',
#                     'Nombre': 'Partido Demócrata Cristiano',
#                     'Alias': 'DC'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(1998, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2002, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'DC',
#                     'Nombre': 'Partido Demócrata Cristiano',
#                     'Alias': 'DC'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2014, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2018, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'DC',
#                     'Nombre': 'Partido Demócrata Cristiano',
#                     'Alias': 'DC'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(1994, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(1998, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'DC',
#                     'Nombre': 'Partido Demócrata Cristiano',
#                     'Alias': 'DC'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 939,
#     'Nombre': 'Gustavo',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Hasbún',
#     'ApellidoMaterno': 'Selume',
#     'FechaNacimiento': datetime.datetime(1972, 8, 2, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2014, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2018, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'UDI',
#                     'Nombre': 'Unión Demócrata Independiente',
#                     'Alias': 'UDI'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2010, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2014, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'UDI',
#                     'Nombre': 'Unión Demócrata Independiente',
#                     'Alias': 'UDI'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 944,
#     'Nombre': 'Andrea',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Molina',
#     'ApellidoMaterno': 'Oliva',
#     'FechaNacimiento': datetime.datetime(1970, 3, 28, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Femenino',
#         'Valor': 0
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2010, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2014, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'UDI',
#                     'Nombre': 'Unión Demócrata Independiente',
#                     'Alias': 'UDI'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2014, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2018, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'UDI',
#                     'Nombre': 'Unión Demócrata Independiente',
#                     'Alias': 'UDI'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 950,
#     'Nombre': 'René',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Saffirio',
#     'ApellidoMaterno': 'Espinoza',
#     'FechaNacimiento': datetime.datetime(1955, 10, 9, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2010, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2014, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'DC',
#                     'Nombre': 'Partido Demócrata Cristiano',
#                     'Alias': 'DC'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2014, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2018, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'IND',
#                     'Nombre': 'Independientes',
#                     'Alias': 'IND'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2018, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2022, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'IND',
#                     'Nombre': 'Independientes',
#                     'Alias': 'IND'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 962,
#     'Nombre': 'Carlos',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Vilches',
#     'ApellidoMaterno': 'Guzmán',
#     'FechaNacimiento': datetime.datetime(1944, 10, 20, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(1994, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(1998, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'RN',
#                     'Nombre': 'Renovación Nacional',
#                     'Alias': 'RN'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2010, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2014, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'UDI',
#                     'Nombre': 'Unión Demócrata Independiente',
#                     'Alias': 'UDI'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2002, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2006, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'RN',
#                     'Nombre': 'Renovación Nacional',
#                     'Alias': 'RN'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(1990, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(1994, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'RN',
#                     'Nombre': 'Renovación Nacional',
#                     'Alias': 'RN'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(1998, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2002, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'RN',
#                     'Nombre': 'Renovación Nacional',
#                     'Alias': 'RN'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 956,
#     'Nombre': 'Guillermo',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Teillier',
#     'ApellidoMaterno': 'Del Valle',
#     'FechaNacimiento': datetime.datetime(1943, 10, 29, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2010, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2014, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'PC',
#                     'Nombre': 'Partido Comunista',
#                     'Alias': 'PC'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2018, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2022, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'PC',
#                     'Nombre': 'Partido Comunista',
#                     'Alias': 'PC'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2014, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2018, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'PC',
#                     'Nombre': 'Partido Comunista',
#                     'Alias': 'PC'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 808,
#     'Nombre': 'Pedro',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Araya',
#     'ApellidoMaterno': 'Guerrero',
#     'FechaNacimiento': datetime.datetime(1974, 6, 16, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2006, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2010, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'IND',
#                     'Nombre': 'Independientes',
#                     'Alias': 'IND'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2010, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2014, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'PRI',
#                     'Nombre': 'Partido Regionalista Independiente',
#                     'Alias': 'PRI'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2002, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2006, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'DC',
#                     'Nombre': 'Partido Demócrata Cristiano',
#                     'Alias': 'DC'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 800,
#     'Nombre': 'Enrique',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Accorsi',
#     'ApellidoMaterno': 'Opazo',
#     'FechaNacimiento': datetime.datetime(1948, 8, 17, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2010, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2014, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'PPD',
#                     'Nombre': 'Partido Por la Democracia',
#                     'Alias': 'PPD'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2002, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2006, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'PPD',
#                     'Nombre': 'Partido Por la Democracia',
#                     'Alias': 'PPD'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2006, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2010, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'PPD',
#                     'Nombre': 'Partido Por la Democracia',
#                     'Alias': 'PPD'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 802,
#     'Nombre': 'Sergio',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Aguiló',
#     'ApellidoMaterno': 'Melo',
#     'FechaNacimiento': datetime.datetime(1953, 2, 9, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(1990, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(1994, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'PS',
#                     'Nombre': 'Partido Socialista',
#                     'Alias': 'PS'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(1994, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(1998, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'PS',
#                     'Nombre': 'Partido Socialista',
#                     'Alias': 'PS'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2006, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2010, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'PS',
#                     'Nombre': 'Partido Socialista',
#                     'Alias': 'PS'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2010, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2014, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'IC',
#                     'Nombre': 'Izquierda Ciudadana',
#                     'Alias': 'IC'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(1998, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2002, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'PS',
#                     'Nombre': 'Partido Socialista',
#                     'Alias': 'PS'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2002, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2006, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'PS',
#                     'Nombre': 'Partido Socialista',
#                     'Alias': 'PS'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2014, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2018, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'IC',
#                     'Nombre': 'Izquierda Ciudadana',
#                     'Alias': 'IC'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 804,
#     'Nombre': 'Isabel',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Allende',
#     'ApellidoMaterno': 'Bussi',
#     'FechaNacimiento': datetime.datetime(1945, 1, 18, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Femenino',
#         'Valor': 0
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(1994, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(1998, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'PS',
#                     'Nombre': 'Partido Socialista',
#                     'Alias': 'PS'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(1998, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2002, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'PS',
#                     'Nombre': 'Partido Socialista',
#                     'Alias': 'PS'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2002, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2006, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'PS',
#                     'Nombre': 'Partido Socialista',
#                     'Alias': 'PS'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2006, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2010, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'PS',
#                     'Nombre': 'Partido Socialista',
#                     'Alias': 'PS'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 805,
#     'Nombre': 'Claudio',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Alvarado',
#     'ApellidoMaterno': 'Andrade',
#     'FechaNacimiento': datetime.datetime(1960, 2, 7, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2006, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2010, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'UDI',
#                     'Nombre': 'Unión Demócrata Independiente',
#                     'Alias': 'UDI'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(1998, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2002, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'UDI',
#                     'Nombre': 'Unión Demócrata Independiente',
#                     'Alias': 'UDI'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2002, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2006, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'UDI',
#                     'Nombre': 'Unión Demócrata Independiente',
#                     'Alias': 'UDI'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(1994, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(1998, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'UDI',
#                     'Nombre': 'Unión Demócrata Independiente',
#                     'Alias': 'UDI'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 807,
#     'Nombre': 'Rodrigo',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Alvarez',
#     'ApellidoMaterno': 'Zenteno',
#     'FechaNacimiento': datetime.datetime(1966, 7, 30, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2006, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2010, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'UDI',
#                     'Nombre': 'Unión Demócrata Independiente',
#                     'Alias': 'UDI'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(1998, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2002, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'UDI',
#                     'Nombre': 'Unión Demócrata Independiente',
#                     'Alias': 'UDI'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2002, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2006, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'UDI',
#                     'Nombre': 'Unión Demócrata Independiente',
#                     'Alias': 'UDI'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 806,
#     'Nombre': 'Pedro Pablo',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Alvarez-Salamanca',
#     'ApellidoMaterno': 'Büchi',
#     'FechaNacimiento': datetime.datetime(1948, 4, 10, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(1990, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(1994, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'RN',
#                     'Nombre': 'Renovación Nacional',
#                     'Alias': 'RN'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(1994, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(1998, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'RN',
#                     'Nombre': 'Renovación Nacional',
#                     'Alias': 'RN'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2006, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2010, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'RN',
#                     'Nombre': 'Renovación Nacional',
#                     'Alias': 'RN'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(1998, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2002, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'RN',
#                     'Nombre': 'Renovación Nacional',
#                     'Alias': 'RN'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2002, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2006, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'RN',
#                     'Nombre': 'Renovación Nacional',
#                     'Alias': 'RN'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 921,
#     'Nombre': 'Lily',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Pérez',
#     'ApellidoMaterno': 'San Martín',
#     'FechaNacimiento': datetime.datetime(1963, 5, 10, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Femenino',
#         'Valor': 0
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2002, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2006, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'RN',
#                     'Nombre': 'Renovación Nacional',
#                     'Alias': 'RN'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2008, 10, 14, 0, 0),
#                 'FechaTermino': datetime.datetime(2012, 10, 13, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'RN',
#                     'Nombre': 'Renovación Nacional',
#                     'Alias': 'RN'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(1998, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2002, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'RN',
#                     'Nombre': 'Renovación Nacional',
#                     'Alias': 'RN'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 810,
#     'Nombre': 'Gabriel',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Ascencio',
#     'ApellidoMaterno': 'Mansilla',
#     'FechaNacimiento': datetime.datetime(1953, 10, 25, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2006, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2010, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'DC',
#                     'Nombre': 'Partido Demócrata Cristiano',
#                     'Alias': 'DC'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2010, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2014, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'DC',
#                     'Nombre': 'Partido Demócrata Cristiano',
#                     'Alias': 'DC'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(1998, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2002, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'DC',
#                     'Nombre': 'Partido Demócrata Cristiano',
#                     'Alias': 'DC'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2018, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2022, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'DC',
#                     'Nombre': 'Partido Demócrata Cristiano',
#                     'Alias': 'DC'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2002, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2006, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'DC',
#                     'Nombre': 'Partido Demócrata Cristiano',
#                     'Alias': 'DC'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(1994, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(1998, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'DC',
#                     'Nombre': 'Partido Demócrata Cristiano',
#                     'Alias': 'DC'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 811,
#     'Nombre': 'Ramón',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Barros',
#     'ApellidoMaterno': 'Montero',
#     'FechaNacimiento': datetime.datetime(1958, 3, 5, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2010, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2014, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'UDI',
#                     'Nombre': 'Unión Demócrata Independiente',
#                     'Alias': 'UDI'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2018, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2022, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'UDI',
#                     'Nombre': 'Unión Demócrata Independiente',
#                     'Alias': 'UDI'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2014, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2018, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'UDI',
#                     'Nombre': 'Unión Demócrata Independiente',
#                     'Alias': 'UDI'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2006, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2010, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'UDI',
#                     'Nombre': 'Unión Demócrata Independiente',
#                     'Alias': 'UDI'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2002, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2006, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'UDI',
#                     'Nombre': 'Unión Demócrata Independiente',
#                     'Alias': 'UDI'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 812,
#     'Nombre': 'Eugenio',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Bauer',
#     'ApellidoMaterno': 'Jouanne',
#     'FechaNacimiento': datetime.datetime(1947, 5, 20, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2006, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2010, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'UDI',
#                     'Nombre': 'Unión Demócrata Independiente',
#                     'Alias': 'UDI'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2010, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2014, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'UDI',
#                     'Nombre': 'Unión Demócrata Independiente',
#                     'Alias': 'UDI'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2002, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2006, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'UDI',
#                     'Nombre': 'Unión Demócrata Independiente',
#                     'Alias': 'UDI'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 813,
#     'Nombre': 'Germán',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Becker',
#     'ApellidoMaterno': 'Alvear',
#     'FechaNacimiento': datetime.datetime(1955, 3, 13, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2010, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2014, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'RN',
#                     'Nombre': 'Renovación Nacional',
#                     'Alias': 'RN'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2002, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2006, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'RN',
#                     'Nombre': 'Renovación Nacional',
#                     'Alias': 'RN'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2014, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2018, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'RN',
#                     'Nombre': 'Renovación Nacional',
#                     'Alias': 'RN'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2006, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2010, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'RN',
#                     'Nombre': 'Renovación Nacional',
#                     'Alias': 'RN'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 814,
#     'Nombre': 'Mario',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Bertolino',
#     'ApellidoMaterno': 'Rendic',
#     'FechaNacimiento': datetime.datetime(1954, 2, 3, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2006, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2010, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'RN',
#                     'Nombre': 'Renovación Nacional',
#                     'Alias': 'RN'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2010, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2014, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'RN',
#                     'Nombre': 'Renovación Nacional',
#                     'Alias': 'RN'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(1998, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2002, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'RN',
#                     'Nombre': 'Renovación Nacional',
#                     'Alias': 'RN'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2002, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2006, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'RN',
#                     'Nombre': 'Renovación Nacional',
#                     'Alias': 'RN'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 816,
#     'Nombre': 'Jorge',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Burgos',
#     'ApellidoMaterno': 'Varela',
#     'FechaNacimiento': datetime.datetime(1956, 6, 24, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2010, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2014, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'DC',
#                     'Nombre': 'Partido Demócrata Cristiano',
#                     'Alias': 'DC'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2002, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2006, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'DC',
#                     'Nombre': 'Partido Demócrata Cristiano',
#                     'Alias': 'DC'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2006, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2010, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'DC',
#                     'Nombre': 'Partido Demócrata Cristiano',
#                     'Alias': 'DC'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 817,
#     'Nombre': 'Juan',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Bustos',
#     'ApellidoMaterno': 'Ramírez',
#     'FechaNacimiento': datetime.datetime(1935, 12, 8, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2006, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2010, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'PS',
#                     'Nombre': 'Partido Socialista',
#                     'Alias': 'PS'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(1998, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2002, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'PS',
#                     'Nombre': 'Partido Socialista',
#                     'Alias': 'PS'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2002, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2006, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'PS',
#                     'Nombre': 'Partido Socialista',
#                     'Alias': 'PS'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 818,
#     'Nombre': 'Alberto',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Cardemil',
#     'ApellidoMaterno': 'Herrera',
#     'FechaNacimiento': datetime.datetime(1945, 11, 1, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2006, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2010, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'IND',
#                     'Nombre': 'Independientes',
#                     'Alias': 'IND'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2010, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2014, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'RN',
#                     'Nombre': 'Renovación Nacional',
#                     'Alias': 'RN'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(1998, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2002, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'RN',
#                     'Nombre': 'Renovación Nacional',
#                     'Alias': 'RN'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2002, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2006, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'RN',
#                     'Nombre': 'Renovación Nacional',
#                     'Alias': 'RN'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(1994, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(1998, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'RN',
#                     'Nombre': 'Renovación Nacional',
#                     'Alias': 'RN'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 819,
#     'Nombre': 'Guillermo',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Ceroni',
#     'ApellidoMaterno': 'Fuentes',
#     'FechaNacimiento': datetime.datetime(1946, 7, 30, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(1994, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(1998, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'PPD',
#                     'Nombre': 'Partido Por la Democracia',
#                     'Alias': 'PPD'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2010, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2014, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'PPD',
#                     'Nombre': 'Partido Por la Democracia',
#                     'Alias': 'PPD'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(1998, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2002, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'PPD',
#                     'Nombre': 'Partido Por la Democracia',
#                     'Alias': 'PPD'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2002, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2006, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'PPD',
#                     'Nombre': 'Partido Por la Democracia',
#                     'Alias': 'PPD'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2014, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2018, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'PPD',
#                     'Nombre': 'Partido Por la Democracia',
#                     'Alias': 'PPD'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2006, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2010, 3, 10, 23, 59, 59),
#                 'Partido': {
# ...
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2022, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2025, 8, 3, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'IND',
#                     'Nombre': 'Independientes',
#                     'Alias': 'IND'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2025, 8, 4, 0, 0),
#                 'FechaTermino': datetime.datetime(2026, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'PREP',
#                     'Nombre': 'Partido Republicano',
#                     'Alias': 'PREP'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 1173,
#     'Nombre': 'Daniela',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Serrano',
#     'ApellidoMaterno': 'Salazar',
#     'FechaNacimiento': datetime.datetime(1995, 3, 17, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Femenino',
#         'Valor': 0
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2022, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2026, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'PC',
#                     'Nombre': 'Partido Comunista',
#                     'Alias': 'PC'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 1174,
#     'Nombre': 'Marco Antonio',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Sulantay',
#     'ApellidoMaterno': 'Olivares',
#     'FechaNacimiento': datetime.datetime(1973, 3, 31, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2022, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2026, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'UDI',
#                     'Nombre': 'Unión Demócrata Independiente',
#                     'Alias': 'UDI'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 1175,
#     'Nombre': 'Cristián',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Tapia',
#     'ApellidoMaterno': 'Ramos',
#     'FechaNacimiento': datetime.datetime(1968, 7, 14, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2022, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2026, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'IND',
#                     'Nombre': 'Independientes',
#                     'Alias': 'IND'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 1176,
#     'Nombre': 'Hotuiti',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Teao',
#     'ApellidoMaterno': 'Drago',
#     'FechaNacimiento': datetime.datetime(1977, 8, 1, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2022, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2026, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'IND',
#                     'Nombre': 'Independientes',
#                     'Alias': 'IND'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 1178,
#     'Nombre': 'Héctor',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Ulloa',
#     'ApellidoMaterno': 'Aguilera',
#     'FechaNacimiento': datetime.datetime(1969, 8, 6, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2022, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2026, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'IND',
#                     'Nombre': 'Independientes',
#                     'Alias': 'IND'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 1179,
#     'Nombre': 'Alberto',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Undurraga',
#     'ApellidoMaterno': 'Vicuña',
#     'FechaNacimiento': datetime.datetime(1969, 6, 17, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2022, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2026, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'DC',
#                     'Nombre': 'Partido Demócrata Cristiano',
#                     'Alias': 'DC'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 1182,
#     'Nombre': 'Sebastián',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Videla',
#     'ApellidoMaterno': 'Castillo',
#     'FechaNacimiento': datetime.datetime(1986, 4, 29, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2022, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2026, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'IND',
#                     'Nombre': 'Independientes',
#                     'Alias': 'IND'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 1183,
#     'Nombre': 'Flor',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Weisse',
#     'ApellidoMaterno': 'Novoa',
#     'FechaNacimiento': datetime.datetime(1960, 3, 27, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Femenino',
#         'Valor': 0
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2022, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2026, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'UDI',
#                     'Nombre': 'Unión Demócrata Independiente',
#                     'Alias': 'UDI'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 1104,
#     'Nombre': 'Chiara',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Barchiesi',
#     'ApellidoMaterno': 'Chávez',
#     'FechaNacimiento': datetime.datetime(1996, 12, 22, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Femenino',
#         'Valor': 0
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2022, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2026, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'PREP',
#                     'Nombre': 'Partido Republicano',
#                     'Alias': 'PREP'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 1113,
#     'Nombre': 'Marta',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Bravo',
#     'ApellidoMaterno': 'Salinas',
#     'FechaNacimiento': datetime.datetime(1976, 2, 25, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Femenino',
#         'Valor': 0
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2022, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2026, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'UDI',
#                     'Nombre': 'Unión Demócrata Independiente',
#                     'Alias': 'UDI'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 1129,
#     'Nombre': 'Andrés',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Giordano',
#     'ApellidoMaterno': 'Salazar',
#     'FechaNacimiento': datetime.datetime(1986, 12, 29, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2022, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2024, 7, 2, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'IND',
#                     'Nombre': 'Independientes',
#                     'Alias': 'IND'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2024, 7, 3, 0, 0),
#                 'FechaTermino': datetime.datetime(2026, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'FA',
#                     'Nombre': 'Frente Amplio',
#                     'Alias': 'FA'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 1156,
#     'Nombre': 'Hernán',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Palma',
#     'ApellidoMaterno': 'Pérez',
#     'FechaNacimiento': datetime.datetime(1958, 11, 3, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2022, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2026, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'IND',
#                     'Nombre': 'Independientes',
#                     'Alias': 'IND'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 1106,
#     'Nombre': 'Miguel Ángel',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Becker',
#     'ApellidoMaterno': 'Alvear',
#     'FechaNacimiento': datetime.datetime(1960, 10, 7, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2022, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2026, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'RN',
#                     'Nombre': 'Renovación Nacional',
#                     'Alias': 'RN'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 1118,
#     'Nombre': 'Ricardo',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Cifuentes',
#     'ApellidoMaterno': 'Lillo',
#     'FechaNacimiento': datetime.datetime(1962, 9, 12, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2022, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2026, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'DC',
#                     'Nombre': 'Partido Demócrata Cristiano',
#                     'Alias': 'DC'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 1135,
#     'Nombre': 'Johannes',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Kaiser',
#     'ApellidoMaterno': 'Barents-Von Hohenhagen',
#     'FechaNacimiento': datetime.datetime(1976, 1, 5, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2022, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2024, 1, 9, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'PREP',
#                     'Nombre': 'Partido Republicano',
#                     'Alias': 'PREP'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2024, 1, 10, 0, 0),
#                 'FechaTermino': datetime.datetime(2025, 6, 15, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'IND',
#                     'Nombre': 'Independientes',
#                     'Alias': 'IND'
#                 }
#             },
#             {
#                 'FechaInicio': datetime.datetime(2025, 6, 16, 0, 0),
#                 'FechaTermino': datetime.datetime(2026, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'PNL',
#                     'Nombre': 'Partido Nacional Libertario',
#                     'Alias': 'PNL'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 1144,
#     'Nombre': 'Christian',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Matheson',
#     'ApellidoMaterno': 'Villán',
#     'FechaNacimiento': datetime.datetime(1957, 12, 17, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2022, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2026, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'IND',
#                     'Nombre': 'Independientes',
#                     'Alias': 'IND'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 1149,
#     'Nombre': 'Carla',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Morales',
#     'ApellidoMaterno': 'Maldonado',
#     'FechaNacimiento': datetime.datetime(1977, 10, 27, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Femenino',
#         'Valor': 0
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2022, 3, 11, 0, 0),
#                 'FechaTermino': datetime.datetime(2026, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'RN',
#                     'Nombre': 'Renovación Nacional',
#                     'Alias': 'RN'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 1185,
#     'Nombre': 'Arturo',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Barrios',
#     'ApellidoMaterno': 'Oteíza',
#     'FechaNacimiento': datetime.datetime(1967, 7, 22, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2025, 5, 6, 0, 0),
#                 'FechaTermino': datetime.datetime(2026, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'PS',
#                     'Nombre': 'Partido Socialista',
#                     'Alias': 'PS'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 1184,
#     'Nombre': 'Roberto',
#     'Nombre2': None,
#     'ApellidoPaterno': 'Celedón',
#     'ApellidoMaterno': 'Fernández',
#     'FechaNacimiento': datetime.datetime(1947, 1, 31, 0, 0),
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': {
#         '_value_1': 'Masculino',
#         'Valor': 1
#     },
#     'Militancias': {
#         'Militancia': [
#             {
#                 'FechaInicio': datetime.datetime(2025, 1, 8, 0, 0),
#                 'FechaTermino': datetime.datetime(2026, 3, 10, 23, 59, 59),
#                 'Partido': {
#                     'Id': 'IND',
#                     'Nombre': 'Independientes',
#                     'Alias': 'IND'
#                 }
#             }
#         ]
#     }
# }, {
#     'Id': 9999,
#     'Nombre': '.',
#     'Nombre2': None,
#     'ApellidoPaterno': None,
#     'ApellidoMaterno': '.',
#     'FechaNacimiento': None,
#     'FechaDefucion': None,
#     'RUT': None,
#     'RUTDV': None,
#     'Sexo': None,
#     'Militancias': None
# }]

# %%
def nombre_completo(r):
    return " ".join([
        r["Nombre"] or "",
        r["Nombre2"] or "",
        r["ApellidoPaterno"] or "",
        r["ApellidoMaterno"] or "",
    ]).strip()

# 1) Personas (una fila por diputada/o)
def flatten_person(r):
    # Normaliza 'Sexo' a dict con llaves esperadas si viene None o faltante
    sexo = r["Sexo"] if r["Sexo"] else {"_value_1": None, "Valor": None}
    return {
        "dip_id": r["Id"],                          # asumes que siempre existe
        "nombre": r["Nombre"],
        "nombre2": r["Nombre2"],
        "ap_pat": r["ApellidoPaterno"],
        "ap_mat": r["ApellidoMaterno"],
        "nombre_completo": nombre_completo(r),
        "fecha_nac": r["FechaNacimiento"],
        "fecha_def": r["FechaDefucion"],            # ojo: tu ejemplo usa 'FechaDefucion'
        "rut": r["RUT"],
        "rut_dv": r["RUTDV"],
        "sexo": (sexo["_value_1"] if ("_value_1" in sexo and sexo["_value_1"] is not None) else None),
        "sexo_valor": (sexo["Valor"] if ("Valor" in sexo and sexo["Valor"] is not None) else None),
    }

df_personas = pd.DataFrame([flatten_person(r) for r in res])
df_personas
# Out:
#      dip_id        nombre nombre2     ap_pat     ap_mat  \
# 0       208        Víctor    None      Pérez     Varela
# 1       485         Jorge    None    Pizarro       Soto
# 2       684        Sergio    None    Pizarro     Mackay
# 3       696  José Alfonso    None  Rodríguez    Del Río
# 4       951         David    None   Sandoval      Plaza
# ..      ...           ...     ...        ...        ...
# 549    1144     Christian    None   Matheson     Villán
# 550    1149         Carla    None    Morales  Maldonado
# 551    1185        Arturo    None    Barrios     Oteíza
# 552    1184       Roberto    None    Celedón  Fernández
# 553    9999             .    None       None          .
#
#                      nombre_completo  fecha_nac fecha_def   rut rut_dv  \
# 0               Víctor  Pérez Varela 1954-10-18      None  None   None
# 1                Jorge  Pizarro Soto        NaT      None  None   None
# 2             Sergio  Pizarro Mackay        NaT      None  None   None
# 3    José Alfonso  Rodríguez Del Río        NaT      None  None   None
# 4              David  Sandoval Plaza 1952-10-20      None  None   None
# ..                               ...        ...       ...   ...    ...
# 549       Christian  Matheson Villán 1957-12-17      None  None   None
# 550         Carla  Morales Maldonado 1977-10-27      None  None   None
# 551           Arturo  Barrios Oteíza 1967-07-22      None  None   None
# 552       Roberto  Celedón Fernández 1947-01-31      None  None   None
# 553                            .   .        NaT      None  None   None
#
#           sexo  sexo_valor
# 0    Masculino         1.0
# 1    Masculino         1.0
# 2    Masculino         1.0
# 3    Masculino         1.0
# 4    Masculino         1.0
# ..         ...         ...
# 549  Masculino         1.0
# 550   Femenino         0.0
# 551  Masculino         1.0
# 552  Masculino         1.0
# 553       None         NaN
#
# [554 rows x 12 columns]

# %%
df_personas.isnull().sum()
# Out:
# dip_id               0
# nombre               0
# nombre2            554
# ap_pat               1
# ap_mat               1
# nombre_completo      0
# fecha_nac          126
# fecha_def          554
# rut                554
# rut_dv             554
# sexo                 1
# sexo_valor           1
# dtype: int64

# %%
df_personas.drop(["nombre2", "fecha_def", "rut", "rut_dv"], axis=1, inplace=True)
df_personas.drop(df_personas.tail(1).index,inplace=True)
df_personas
# Out:
#      dip_id        nombre     ap_pat                  ap_mat  \
# 0       208        Víctor      Pérez                  Varela
# 1       485         Jorge    Pizarro                    Soto
# 2       684        Sergio    Pizarro                  Mackay
# 3       696  José Alfonso  Rodríguez                 Del Río
# 4       951         David   Sandoval                   Plaza
# ..      ...           ...        ...                     ...
# 548    1135      Johannes     Kaiser  Barents-Von Hohenhagen
# 549    1144     Christian   Matheson                  Villán
# 550    1149         Carla    Morales               Maldonado
# 551    1185        Arturo    Barrios                  Oteíza
# 552    1184       Roberto    Celedón               Fernández
#
#                              nombre_completo  fecha_nac       sexo  sexo_valor
# 0                       Víctor  Pérez Varela 1954-10-18  Masculino         1.0
# 1                        Jorge  Pizarro Soto        NaT  Masculino         1.0
# 2                     Sergio  Pizarro Mackay        NaT  Masculino         1.0
# 3            José Alfonso  Rodríguez Del Río        NaT  Masculino         1.0
# 4                      David  Sandoval Plaza 1952-10-20  Masculino         1.0
# ..                                       ...        ...        ...         ...
# 548  Johannes  Kaiser Barents-Von Hohenhagen 1976-01-05  Masculino         1.0
# 549               Christian  Matheson Villán 1957-12-17  Masculino         1.0
# 550                 Carla  Morales Maldonado 1977-10-27   Femenino         0.0
# 551                   Arturo  Barrios Oteíza 1967-07-22  Masculino         1.0
# 552               Roberto  Celedón Fernández 1947-01-31  Masculino         1.0
#
# [553 rows x 8 columns]

# %%
# 2) Militancias (una fila por período de militancia)
rows = []
for r in res:
    if r["Militancias"]:
        mil = r["Militancias"]["Militancia"]
        # por si a veces viene un dict en vez de lista, SIN usar .get
        mil_list = mil if isinstance(mil, list) else [mil]
        for m in mil_list:
            rows.append({
                "dip_id": r["Id"],
                "fecha_inicio": m["FechaInicio"],
                "fecha_termino": m["FechaTermino"],
                "partido_id": m["Partido"]["Id"],
                "partido_nombre": m["Partido"]["Nombre"],
                "partido_alias": m["Partido"]["Alias"]
            })
        
df_militancias = pd.DataFrame(rows)
df_militancias
# Out:
#       dip_id fecha_inicio       fecha_termino partido_id  \
# 0        208   1990-03-11 1994-03-10 23:59:59        UDI
# 1        208   1998-03-11 2002-03-10 23:59:59        UDI
# 2        208   2002-03-11 2006-03-10 23:59:59        UDI
# 3        208   1994-03-11 1998-03-10 23:59:59        UDI
# 4        485   1990-03-11 1994-03-10 23:59:59         DC
# ...      ...          ...                 ...        ...
# 1267    1135   2025-06-16 2026-03-10 23:59:59        PNL
# 1268    1144   2022-03-11 2026-03-10 23:59:59        IND
# 1269    1149   2022-03-11 2026-03-10 23:59:59         RN
# 1270    1185   2025-05-06 2026-03-10 23:59:59         PS
# 1271    1184   2025-01-08 2026-03-10 23:59:59        IND
#
#                      partido_nombre partido_alias
# 0     Unión Demócrata Independiente           UDI
# 1     Unión Demócrata Independiente           UDI
# 2     Unión Demócrata Independiente           UDI
# 3     Unión Demócrata Independiente           UDI
# 4       Partido Demócrata Cristiano            DC
# ...                             ...           ...
# 1267    Partido Nacional Libertario           PNL
# 1268                 Independientes           IND
# 1269            Renovación Nacional            RN
# 1270             Partido Socialista            PS
# 1271                 Independientes           IND
#
# [1272 rows x 6 columns]

# %%
for col in ["fecha_nac", "fecha_def"]:
    if col in df_personas.columns:
        df_personas[col] = pd.to_datetime(df_personas[col], errors="coerce")
for col in ["fecha_inicio", "fecha_termino"]:
    if col in df_militancias.columns:
        df_militancias[col] = pd.to_datetime(df_militancias[col], errors="coerce")

hoy = pd.Timestamp.today().normalize()
if "es_vigente" not in df_militancias.columns:
    df_militancias["es_vigente"] = (
        df_militancias["fecha_inicio"].notna() &
        (df_militancias["fecha_inicio"] <= hoy) &
        (df_militancias["fecha_termino"].isna() | (df_militancias["fecha_termino"] >= hoy))
    )

# --- 1) Número total de militancias por persona ---
df_militancias["n_militancias_total"] = (
    df_militancias.groupby("dip_id")["dip_id"].transform("size")
)
# (Opcional) Orden cronológico de militancias por persona (útil para análisis)
df_militancias = df_militancias.sort_values(["dip_id","fecha_inicio","fecha_termino"])
# (Opcional) Guardar
# df_militancias.to_csv("militancias.csv", index=False, encoding="utf-8-sig", date_format="%Y-%m-%d")
# df_personas.to_csv("personas.csv", index=False, encoding="utf-8-sig", date_format="%Y-%m-%d")


df_militancias.head()
# Out:
#      dip_id fecha_inicio       fecha_termino partido_id  \
# 571       1   1990-03-11 1994-03-10 23:59:59         DC
# 573       1   1994-03-11 1998-03-10 23:59:59         DC
# 572       1   1998-03-11 2002-03-10 23:59:59         DC
# 574       3   1998-03-11 2002-03-10 23:59:59         RN
# 610       8   1998-03-11 2002-03-10 23:59:59         DC
#
#                   partido_nombre partido_alias  es_vigente  \
# 571  Partido Demócrata Cristiano            DC       False
# 573  Partido Demócrata Cristiano            DC       False
# 572  Partido Demócrata Cristiano            DC       False
# 574          Renovación Nacional            RN       False
# 610  Partido Demócrata Cristiano            DC       False
#
#      n_militancias_total
# 571                    3
# 573                    3
# 572                    3
# 574                    1
# 610                    1

# %%
# 4) Partido “actual”: última militancia por persona (según fecha_termino)
if not df_militancias.empty:
    idx_ult = (df_militancias
               .sort_values(["dip_id", "fecha_termino"], na_position="last")
               .groupby("dip_id")
               .tail(1)
               .index)
    df_actual = (df_militancias.loc[idx_ult, ["dip_id","partido_id","partido_nombre","partido_alias", "es_vigente", "n_militancias_total"]]
                 .rename(columns={
                     "partido_id":"partido_actual_id",
                     "partido_nombre":"partido_actual_nombre",
                     "partido_alias":"partido_actual_alias"
                 }))
    df_personas = df_personas.merge(df_actual, on="dip_id", how="left")

print("Militancias:")
print(df_militancias.head())
# Out:
# Militancias:
#      dip_id fecha_inicio       fecha_termino partido_id  \
# 571       1   1990-03-11 1994-03-10 23:59:59         DC
# 573       1   1994-03-11 1998-03-10 23:59:59         DC
# 572       1   1998-03-11 2002-03-10 23:59:59         DC
# 574       3   1998-03-11 2002-03-10 23:59:59         RN
# 610       8   1998-03-11 2002-03-10 23:59:59         DC
#
#                   partido_nombre partido_alias  es_vigente  \
# 571  Partido Demócrata Cristiano            DC       False
# 573  Partido Demócrata Cristiano            DC       False
# 572  Partido Demócrata Cristiano            DC       False
# 574          Renovación Nacional            RN       False
# 610  Partido Demócrata Cristiano            DC       False
#
#      n_militancias_total
# 571                    3
# 573                    3
# 572                    3
# 574                    1
# 610                    1

# %%
df_personas
# Out:
#      dip_id        nombre     ap_pat                  ap_mat  \
# 0       208        Víctor      Pérez                  Varela
# 1       485         Jorge    Pizarro                    Soto
# 2       684        Sergio    Pizarro                  Mackay
# 3       696  José Alfonso  Rodríguez                 Del Río
# 4       951         David   Sandoval                   Plaza
# ..      ...           ...        ...                     ...
# 548    1135      Johannes     Kaiser  Barents-Von Hohenhagen
# 549    1144     Christian   Matheson                  Villán
# 550    1149         Carla    Morales               Maldonado
# 551    1185        Arturo    Barrios                  Oteíza
# 552    1184       Roberto    Celedón               Fernández
#
#                              nombre_completo  fecha_nac       sexo  \
# 0                       Víctor  Pérez Varela 1954-10-18  Masculino
# 1                        Jorge  Pizarro Soto        NaT  Masculino
# 2                     Sergio  Pizarro Mackay        NaT  Masculino
# 3            José Alfonso  Rodríguez Del Río        NaT  Masculino
# 4                      David  Sandoval Plaza 1952-10-20  Masculino
# ..                                       ...        ...        ...
# 548  Johannes  Kaiser Barents-Von Hohenhagen 1976-01-05  Masculino
# 549               Christian  Matheson Villán 1957-12-17  Masculino
# 550                 Carla  Morales Maldonado 1977-10-27   Femenino
# 551                   Arturo  Barrios Oteíza 1967-07-22  Masculino
# 552               Roberto  Celedón Fernández 1947-01-31  Masculino
#
#      sexo_valor partido_actual_id          partido_actual_nombre  \
# 0           1.0               UDI  Unión Demócrata Independiente
# 1           1.0                DC    Partido Demócrata Cristiano
# 2           1.0                DC    Partido Demócrata Cristiano
# 3           1.0                RN            Renovación Nacional
# 4           1.0               UDI  Unión Demócrata Independiente
# ..          ...               ...                            ...
# 548         1.0               PNL    Partido Nacional Libertario
# 549         1.0               IND                 Independientes
# 550         0.0                RN            Renovación Nacional
# 551         1.0                PS             Partido Socialista
# 552         1.0               IND                 Independientes
#
#     partido_actual_alias  es_vigente  n_militancias_total
# 0                    UDI       False                    4
# 1                     DC       False                    2
# 2                     DC       False                    1
# 3                     RN       False                    1
# 4                    UDI       False                    2
# ..                   ...         ...                  ...
# 548                  PNL        True                    3
# 549                  IND        True                    1
# 550                   RN        True                    1
# 551                   PS        True                    1
# 552                  IND        True                    1
#
# [553 rows x 13 columns]

# %%
df_personas.to_csv("diputados.csv", index=False, encoding="utf-8-sig", date_format="%Y-%m-%d")

# %%
df_personas.n_militancias_total.hist()
# Out:
# <Axes: >

# %%
df_militancias.head()
# Out:
#      dip_id fecha_inicio       fecha_termino partido_id  \
# 571       1   1990-03-11 1994-03-10 23:59:59         DC
# 573       1   1994-03-11 1998-03-10 23:59:59         DC
# 572       1   1998-03-11 2002-03-10 23:59:59         DC
# 574       3   1998-03-11 2002-03-10 23:59:59         RN
# 610       8   1998-03-11 2002-03-10 23:59:59         DC
#
#                   partido_nombre partido_alias  es_vigente  \
# 571  Partido Demócrata Cristiano            DC       False
# 573  Partido Demócrata Cristiano            DC       False
# 572  Partido Demócrata Cristiano            DC       False
# 574          Renovación Nacional            RN       False
# 610  Partido Demócrata Cristiano            DC       False
#
#      n_militancias_total
# 571                    3
# 573                    3
# 572                    3
# 574                    1
# 610                    1
